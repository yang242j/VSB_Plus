# %% [markdown]
# ## course_info.ipynb - Gathering the course information from the UR website and convert to the JSON or xlwt file.
#
# In this file, using function in the requests packet to get html from the UR website. Then, using the methods in BeautifulSoup handle html text and match the text pattern by the regular expression.
#
# Last, Converting the details to the JSON or xlwt files.
#
# The following URL is about course details:
# https://banner.uregina.ca:17023/ssbprod/bwckctlg.p_disp_dyn_ctlg

# %% [markdown]
# ### Part 1 - Functions about the get the html from the UR website

# %%
import requests
from bs4 import BeautifulSoup
import bs4
import re
import xlwt
import pandas as pd
import os
import copy
# !pip install ipynb
from ipynb.fs.full.Param_SETUP import *
# Out:
# Requirement already satisfied: ipynb in /Users/xinyuliu/opt/anaconda3/lib/python3.8/site-packages (0.5.1)
# All parameter are set up

# %%
def getHTMLText(url, params = None):
    """Get HTML Text 

    Geting the HTML text form the url with params

    Args:
        url: web url
        detail_para: The parameters for the url as dirctory format.

    Returns:
        return the html text

    Raises:
        IOError: Error message will print out
    """
    try:
        kv = {'user-agent': 'Mozilla/5.0'}
        r = requests.get(url, timeout=30, headers=kv, params = params)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return "Connection error"

# detail_url = "https://banner.uregina.ca:17023/ssbprod/bwckctlg.p_disp_course_detail"
# detail_para = {'cat_term_in':'202110',
#         'subj_code_in':'ENSE',
#         'crse_numb_in':'350'}
# html = getHTMLText(detail_url,params=detail_para)
# html

# %%
# elimiate '\n' and '*' in the text 
def eliminate(text):
    """elimiate the space, \n and *

    Remove the front and end space, \n and *

    Args:
        text: text that need to be modified

    Returns:
        return the modified text

    Raises:
        IOError:
    """
    # Remove the *
    text = text.replace('*','')

    # Remove the \n and space
    text = text.strip()
    
    return text

# %%
def parsePage(detail_dict, html):
    """Parsing the page

    Parsing the UoR course infomation page, and append the detail into
    the detail_dict

    Args:
        detail_para: The parameters for the url as dirctory format.
        html: the html text that need to be parsed

    Returns:
        No returns

    Raises:
        IOError: 
    """
    soup = BeautifulSoup(html, "html.parser") # Make the soup for the html

    # Find the course name and information tag
    name_tags = soup.find_all('td',class_='nttitle')
    info_tags =soup.find_all('td', class_='ntdefault')

    for name_tag, info_tag in zip(name_tags, info_tags):
        try:
            # Get the string for facutly, course number and full name
            short_name = name_tag.string.split(' - ')[0] # Eg. ['ENSE 271', 'People-Centred Design']

            title = None 
            for part in name_tag.string.split(' - ')[1:]:
                if title == None: title = part
                else: title += part
            
            faculty, course_num = short_name.split(' ') # Eg. ENSE 271

            if len(re.findall(r'\*{3}.*\*{3}', info_tag.text)) == 0:
                prerequisite = ''
                description = re.findall(r'.*\.', info_tag.text)[0]
            else:
                # Get the string of course description and prerequisit
                prere_text = re.findall(r'\*{3}.*\*{3}', info_tag.text)[0] # Eg. ***Prerequisites: CS 115***
                prerequisite = eliminate(prere_text).split(': ')[1] # Eg. CS 115
                description_text = re.findall(r'[^\*]*\*{3}', info_tag.text)[0]
                description = eliminate(description_text)
            credit_text = re.findall(r'\d\.0{3} Credit hours',info_tag.text)[0]
            credit = credit_text.split('.')[0]

            # Store all the detail into the direction
            detail_dict["short_name"].append(short_name)
            detail_dict["title"].append(title)
            detail_dict["faculty"].append(faculty)
            detail_dict["course_num"].append(course_num)
            detail_dict["credit"].append(credit)
            detail_dict["prerequisite"].append(prerequisite)
            detail_dict["description"].append(description)
        except Exception as e:
            print(short_name, "get errors")
            print(e)

# Example of the funciton:
# detail_dict = {
#         "short_name" : [],
#         "title" : [],
#         "faculty" : [],
#         "course_num" : [],
#         "credit" : [],
#         "prerequisite" : [],
#         "description" : []
#     }

# parsePage(detail_dict, open('Course_info.html').read())
# detail_dict["description"]

# %%
def storeInfo(detail_dict, file_name="Course DB"):
    """Store the course infomation as the excel 

    Convert the course detail dictionary to the excel

    Args:
        detail_para: The parameters for the url as dirctory format.
        file_name: The name of the output excel's name

    Returns:
        No returns

    Raises:
        IOError:
    """
    file_path = os.getcwd()+'/' + file_name +'.xlsx' # Get the file's path and name
    df = pd.DataFrame(detail_dict)
    df.to_excel(file_path, index=False)
    # print(list(detail_dict.keys()))

# storeInfo(detail_dict)

# %%
def crseNumLoop(url, detail_para, course_num_list, detail_dict, parse_method=parsePage):
    """Course number loop

    Go to loop the course number in the list under the same fauctly,
    and, store course infomation in the detail_dict with appending method

    Args:
        url: UoR url for this funciton.
        detail_para: The parameters for the url as dirctory format.
        course_num_list: The list of course number.
        detail_dict: The dirctory that course detail will be stored in.

    Returns:
        No returns

    Raises:
        IOError: Error course number will print out
    """
    count = 0
    total = len(course_num_list)
    num_key = list(detail_para.keys())[2]
    for course_num in course_num_list:
        detail_para[num_key] = course_num
        html = getHTMLText(url, detail_para)
        try :
            parse_method(detail_dict, html)
        except Exception as e:
            print("Error at ", detail_para)
            print(e)
            # continue
        count += 1
        # print('\rCurrent progress:{:.2f}%'.format(count*100/total),end='')

        print("Course number Progress: ",count, "/",total, " ",course_num)
    # print(detail_dict)

# %%
def subjCodeLoop(url, detail_para, subjNum_dict, detail_dict, parse_method=parsePage):
    """subject code loop

    Loop the subject code with the course number list

    Args:
        url: UoR url for this funciton.
        detail_para: The parameters for the url as dirctory format.
        course_num_list: The list of course number.
        subj_code_list: The list of the subject code.
        detail_dict: The dirctory that course detail will be stored in.

    Returns:
        No returns

    Raises:
        IOError: Error course number will print out
    """
    count = 0
    total = len(subjNum_dict)
    subj = list(detail_para.keys())[1]
    for subj_code, crse_num_list in subjNum_dict.items():
        count += 1
        print("Subject code loop :", subj_code, " ", count, "/", total)
        detail_para[subj] = subj_code
        crseNumLoop(url, detail_para, crse_num_list, detail_dict,parse_method=parse_method)

# %% [markdown]
# Store the facult of software information into table

# %%
SSE_course = copy.deepcopy(TempCou)    
PSE_course = copy.deepcopy(TempCou)
ISE_course = copy.deepcopy(TempCou)
EVSE_course = copy.deepcopy(TempCou)
ESE_course = copy.deepcopy(TempCou)
ALL_course = copy.deepcopy(TempCou)

cou_dict_list = [SSE_course, PSE_course, ISE_course, EVSE_course, ESE_course, ALL_course]

# %%
subjCodeLoop(detail_url, detail_para, software_dict, SSE_course)
subjCodeLoop(detail_url, detail_para, petroleum_dict, PSE_course)
subjCodeLoop(detail_url, detail_para, industrial_dict, ISE_course)
subjCodeLoop(detail_url, detail_para, environmental_dict, EVSE_course)
subjCodeLoop(detail_url,detail_para,electronic_dict, ESE_course)
subjCodeLoop(detail_url,detail_para,allCourse_dict, ALL_course)
# Out:
# Subject code loop : CHEM   1 / 12
# Course number Progress:  1 / 1   104
# Subject code loop : ENGG   2 / 12
# Course number Progress:  1 / 5   123
# Course number Progress:  2 / 5   140
# Course number Progress:  3 / 5   100
# Course number Progress:  4 / 5   303
# Course number Progress:  5 / 5   401
# Subject code loop : MATH   3 / 12
# Course number Progress:  1 / 4   110
# Course number Progress:  2 / 4   122
# Course number Progress:  3 / 4   111
# Course number Progress:  4 / 4   213
# Subject code loop : CS   4 / 12
# Course number Progress:  1 / 12   110
# Course number Progress:  2 / 12   115
# Course number Progress:  3 / 12   210
# Course number Progress:  4 / 12   215
# Course number Progress:  5 / 12   340
# Course number Progress:  6 / 12   205
# Course number Progress:  7 / 12   315
# Course number Progress:  8 / 12   330
# Course number Progress:  9 / 12   375
# Course number Progress:  10 / 12   405
# Course number Progress:  11 / 12   425
# Course number Progress:  12 / 12   427
# Subject code loop : ENGL   5 / 12
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 12
# Course number Progress:  1 / 2   119
# Course number Progress:  2 / 2   112
# Subject code loop : ENEL   7 / 12
# Course number Progress:  1 / 8   280
# Course number Progress:  2 / 8   281
# Course number Progress:  3 / 8   282
# Course number Progress:  4 / 8   384
# Course number Progress:  5 / 8   380
# Course number Progress:  6 / 8   387
# Course number Progress:  7 / 8   487
# Course number Progress:  8 / 8   489
# Subject code loop : ENEV   8 / 12
# Course number Progress:  1 / 1   233
# Subject code loop : STAT   9 / 12
# Course number Progress:  1 / 1   289
# Subject code loop : ENSE   10 / 12
# Course number Progress:  1 / 17   352
# Course number Progress:  2 / 17   374
# Course number Progress:  3 / 17   353
# Course number Progress:  4 / 17   470
# Course number Progress:  5 / 17   471
# Course number Progress:  6 / 17   475
# Course number Progress:  7 / 17   400
# Course number Progress:  8 / 17   472
# Course number Progress:  9 / 17   350
# Course number Progress:  10 / 17   477
# Course number Progress:  11 / 17   473
# Course number Progress:  12 / 17   474
# Course number Progress:  13 / 17   479
# Course number Progress:  14 / 17   480
# Course number Progress:  15 / 17   481
# Course number Progress:  16 / 17   482
# Course number Progress:  17 / 17   483
# Subject code loop : BUS   11 / 12
# Course number Progress:  1 / 1   260
# Subject code loop : ECON   12 / 12
# Course number Progress:  1 / 1   201
# Subject code loop : CHEM   1 / 15
# Course number Progress:  1 / 2   104
# Course number Progress:  2 / 2   140
# Subject code loop : ENGG   2 / 15
# Course number Progress:  1 / 7   123
# Course number Progress:  2 / 7   140
# Course number Progress:  3 / 7   100
# Course number Progress:  4 / 7   141
# Course number Progress:  5 / 7   303
# Course number Progress:  6 / 7   330
# Course number Progress:  7 / 7   401
# Subject code loop : MATH   3 / 15
# Course number Progress:  1 / 5   110
# Course number Progress:  2 / 5   122
# Course number Progress:  3 / 5   111
# Course number Progress:  4 / 5   217
# Course number Progress:  5 / 5   213
# Subject code loop : CS   4 / 15
# Course number Progress:  1 / 1   110
# Subject code loop : ENGL   5 / 15
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 15
# Course number Progress:  1 / 1   119
# Subject code loop : ENEL   7 / 15
# Course number Progress:  1 / 1   280
# Subject code loop : ENPE   8 / 15
# Course number Progress:  1 / 21   241
# Course number Progress:  2 / 21   251
# Course number Progress:  3 / 21   300
# Course number Progress:  4 / 21   360
# Course number Progress:  5 / 21   302
# Course number Progress:  6 / 21   370
# Course number Progress:  7 / 21   400
# Course number Progress:  8 / 21   410
# Course number Progress:  9 / 21   440
# Course number Progress:  10 / 21   450
# Course number Progress:  11 / 21   419
# Course number Progress:  12 / 21   486
# Course number Progress:  13 / 21   340
# Course number Progress:  14 / 21   380
# Course number Progress:  15 / 21   435
# Course number Progress:  16 / 21   448
# Course number Progress:  17 / 21   470
# Course number Progress:  18 / 21   475
# Course number Progress:  19 / 21   490
# Course number Progress:  20 / 21   491
# Course number Progress:  21 / 21   492
# Subject code loop : GEOL   9 / 15
# Course number Progress:  1 / 2   102
# Course number Progress:  2 / 2   270
# Subject code loop : ECON   10 / 15
# Course number Progress:  1 / 1   201
# Subject code loop : ENIN   11 / 15
# Course number Progress:  1 / 7   233
# Course number Progress:  2 / 7   253
# Course number Progress:  3 / 7   350
# Course number Progress:  4 / 7   355
# Course number Progress:  5 / 7   433
# Course number Progress:  6 / 7   453
# Course number Progress:  7 / 7   456
# Subject code loop : STAT   12 / 15
# Course number Progress:  1 / 1   289
# Subject code loop : ENE   13 / 15
# Course number Progress:  1 / 2   261
# Course number Progress:  2 / 2   223
# Subject code loop : BUS   14 / 15
# Course number Progress:  1 / 1   260
# Subject code loop : ENEV   15 / 15
# Course number Progress:  1 / 1   422
# Subject code loop : CHEM   1 / 12
# Course number Progress:  1 / 2   104
# Course number Progress:  2 / 2   105
# Subject code loop : ENGG   2 / 12
# Course number Progress:  1 / 8   123
# Course number Progress:  2 / 8   140
# Course number Progress:  3 / 8   100
# Course number Progress:  4 / 8   141
# Course number Progress:  5 / 8   3330
# Course number Progress:  6 / 8   303
# Course number Progress:  7 / 8   401
# Course number Progress:  8 / 8   411
# Subject code loop : MATH   3 / 12
# Course number Progress:  1 / 5   110
# Course number Progress:  2 / 5   122
# Course number Progress:  3 / 5   111
# Course number Progress:  4 / 5   217
# Course number Progress:  5 / 5   213
# Subject code loop : CS   4 / 12
# Course number Progress:  1 / 1   110
# Subject code loop : ENGL   5 / 12
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 12
# Course number Progress:  1 / 1   119
# Subject code loop : ENEL   7 / 12
# Course number Progress:  1 / 4   280
# Course number Progress:  2 / 4   380
# Course number Progress:  3 / 4   389
# Course number Progress:  4 / 4   484
# Subject code loop : ENEV   8 / 12
# Course number Progress:  1 / 2   223
# Course number Progress:  2 / 2   261
# Subject code loop : ENIN   9 / 12
# Course number Progress:  1 / 21   233
# Course number Progress:  2 / 21   241
# Course number Progress:  3 / 21   331
# Course number Progress:  4 / 21   343
# Course number Progress:  5 / 21   253
# Course number Progress:  6 / 21   350
# Course number Progress:  7 / 21   355
# Course number Progress:  8 / 21   430
# Course number Progress:  9 / 21   440
# Course number Progress:  10 / 21   453
# Course number Progress:  11 / 21   340
# Course number Progress:  12 / 21   349
# Course number Progress:  13 / 21   400
# Course number Progress:  14 / 21   444
# Course number Progress:  15 / 21   413
# Course number Progress:  16 / 21   433
# Course number Progress:  17 / 21   370
# Course number Progress:  18 / 21   445
# Course number Progress:  19 / 21   448
# Course number Progress:  20 / 21   456
# Course number Progress:  21 / 21   455
# Subject code loop : STAT   10 / 12
# Course number Progress:  1 / 1   289
# Subject code loop : BUS   11 / 12
# Course number Progress:  1 / 3   260
# Course number Progress:  2 / 3   250
# Course number Progress:  3 / 3   210
# Subject code loop : ECON   12 / 12
# Course number Progress:  1 / 1   201
# Subject code loop : CHEM   1 / 15
# Course number Progress:  1 / 2   104
# Course number Progress:  2 / 2   140
# Subject code loop : ENGG   2 / 15
# Course number Progress:  1 / 8   123
# Course number Progress:  2 / 8   140
# Course number Progress:  3 / 8   100
# Course number Progress:  4 / 8   141
# Course number Progress:  5 / 8   330
# Course number Progress:  6 / 8   303
# Course number Progress:  7 / 8   401
# Course number Progress:  8 / 8   411
# Subject code loop : MATH   3 / 15
# Course number Progress:  1 / 4   110
# Course number Progress:  2 / 4   122
# Course number Progress:  3 / 4   111
# Course number Progress:  4 / 4   213
# Subject code loop : CS   4 / 15
# Course number Progress:  1 / 1   110
# Subject code loop : ENGL   5 / 15
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 15
# Course number Progress:  1 / 1   119
# Subject code loop : ENEV   7 / 15
# Course number Progress:  1 / 24   223
# Course number Progress:  2 / 24   372
# Course number Progress:  3 / 24   261
# Course number Progress:  4 / 24   321
# Course number Progress:  5 / 24   281
# Course number Progress:  6 / 24   334
# Course number Progress:  7 / 24   384
# Course number Progress:  8 / 24   480
# Course number Progress:  9 / 24   360
# Course number Progress:  10 / 24   421
# Course number Progress:  11 / 24   422
# Course number Progress:  12 / 24   440
# Course number Progress:  13 / 24   462
# Course number Progress:  14 / 24   363
# Course number Progress:  15 / 24   383
# Course number Progress:  16 / 24   400
# Course number Progress:  17 / 24   435
# Course number Progress:  18 / 24   415
# Course number Progress:  19 / 24   469
# Course number Progress:  20 / 24   408
# Course number Progress:  21 / 24   445
# Course number Progress:  22 / 24   463
# Course number Progress:  23 / 24   475
# Course number Progress:  24 / 24   484
# Subject code loop : GEOL   8 / 15
# Course number Progress:  1 / 1   102
# Subject code loop : ECON   9 / 15
# Course number Progress:  1 / 1   201
# Subject code loop : ENIN   10 / 15
# Course number Progress:  1 / 5   241
# Course number Progress:  2 / 5   253
# Course number Progress:  3 / 5   350
# Course number Progress:  4 / 5   453
# Course number Progress:  5 / 5   455
# Subject code loop : STAT   11 / 15
# Course number Progress:  1 / 1   289
# Subject code loop : BIOL   12 / 15
# Course number Progress:  1 / 1   233
# Subject code loop : ENPE   13 / 15
# Course number Progress:  1 / 1   490
# Subject code loop : BUS   14 / 15
# Course number Progress:  1 / 2   260
# Course number Progress:  2 / 2   302
# Subject code loop : ENEL   15 / 15
# Course number Progress:  1 / 1   280
# Subject code loop : CHEM   1 / 13
# Course number Progress:  1 / 1   104
# Subject code loop : ENGG   2 / 13
# Course number Progress:  1 / 6   123
# Course number Progress:  2 / 6   140
# Course number Progress:  3 / 6   100
# Course number Progress:  4 / 6   303
# Course number Progress:  5 / 6   401
# Course number Progress:  6 / 6   411
# Subject code loop : MATH   3 / 13
# Course number Progress:  1 / 5   110
# Course number Progress:  2 / 5   122
# Course number Progress:  3 / 5   111
# Course number Progress:  4 / 5   217
# Course number Progress:  5 / 5   213
# Subject code loop : CS   4 / 13
# Course number Progress:  1 / 8   110
# Course number Progress:  2 / 8   115
# Course number Progress:  3 / 8   210
# Course number Progress:  4 / 8   335
# Course number Progress:  5 / 8   340
# Course number Progress:  6 / 8   350
# Course number Progress:  7 / 8   372
# Course number Progress:  8 / 8   375
# Subject code loop : ENGL   5 / 13
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 13
# Course number Progress:  1 / 2   119
# Course number Progress:  2 / 2   201
# Subject code loop : ENEL   7 / 13
# Course number Progress:  1 / 21   280
# Course number Progress:  2 / 21   281
# Course number Progress:  3 / 21   282
# Course number Progress:  4 / 21   383
# Course number Progress:  5 / 21   384
# Course number Progress:  6 / 21   380
# Course number Progress:  7 / 21   390
# Course number Progress:  8 / 21   371
# Course number Progress:  9 / 21   387
# Course number Progress:  10 / 21   400
# Course number Progress:  11 / 21   417
# Course number Progress:  12 / 21   389
# Course number Progress:  13 / 21   393
# Course number Progress:  14 / 21   395
# Course number Progress:  15 / 21   472
# Course number Progress:  16 / 21   482
# Course number Progress:  17 / 21   484
# Course number Progress:  18 / 21   487
# Course number Progress:  19 / 21   489
# Course number Progress:  20 / 21   494
# Course number Progress:  21 / 21   495
# Subject code loop : ENEV   8 / 13
# Course number Progress:  1 / 3   223
# Course number Progress:  2 / 3   261
# Course number Progress:  3 / 3   334
# Subject code loop : STAT   9 / 13
# Course number Progress:  1 / 1   289
# Subject code loop : BUS   10 / 13
# Course number Progress:  1 / 2   260
# Course number Progress:  2 / 2   210
# Subject code loop : ENSE   11 / 13
# Course number Progress:  1 / 3   352
# Course number Progress:  2 / 3   350
# Course number Progress:  3 / 3   481
# Subject code loop : ECON   12 / 13
# Course number Progress:  1 / 1   201
# Subject code loop : ENIN   13 / 13
# Course number Progress:  1 / 3   253
# Course number Progress:  2 / 3   433
# Course number Progress:  3 / 3   440
# Subject code loop : CHEM   1 / 17
# Course number Progress:  1 / 3   104
# Course number Progress:  2 / 3   140
# Course number Progress:  3 / 3   105
# Subject code loop : ENGG   2 / 17
# Course number Progress:  1 / 9   123
# Course number Progress:  2 / 9   140
# Course number Progress:  3 / 9   100
# Course number Progress:  4 / 9   303
# Course number Progress:  5 / 9   401
# Course number Progress:  6 / 9   141
# Course number Progress:  7 / 9   330
# Course number Progress:  8 / 9   3330
# Course number Progress:  9 / 9   411
# Subject code loop : MATH   3 / 17
# Course number Progress:  1 / 5   110
# Course number Progress:  2 / 5   122
# Course number Progress:  3 / 5   111
# Course number Progress:  4 / 5   213
# Course number Progress:  5 / 5   217
# Subject code loop : CS   4 / 17
# Course number Progress:  1 / 15   110
# Course number Progress:  2 / 15   115
# Course number Progress:  3 / 15   210
# Course number Progress:  4 / 15   215
# Course number Progress:  5 / 15   340
# Course number Progress:  6 / 15   205
# Course number Progress:  7 / 15   315
# Course number Progress:  8 / 15   330
# Course number Progress:  9 / 15   375
# Course number Progress:  10 / 15   405
# Course number Progress:  11 / 15   425
# Course number Progress:  12 / 15   427
# Course number Progress:  13 / 15   335
# Course number Progress:  14 / 15   350
# Course number Progress:  15 / 15   372
# Subject code loop : ENGL   5 / 17
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 17
# Course number Progress:  1 / 3   119
# Course number Progress:  2 / 3   112
# Course number Progress:  3 / 3   201
# Subject code loop : ENEL   7 / 17
# Course number Progress:  1 / 21   280
# Course number Progress:  2 / 21   281
# Course number Progress:  3 / 21   282
# Course number Progress:  4 / 21   384
# Course number Progress:  5 / 21   380
# Course number Progress:  6 / 21   387
# Course number Progress:  7 / 21   487
# Course number Progress:  8 / 21   489
# Course number Progress:  9 / 21   389
# Course number Progress:  10 / 21   484
# Course number Progress:  11 / 21   383
# Course number Progress:  12 / 21   390
# Course number Progress:  13 / 21   371
# Course number Progress:  14 / 21   400
# Course number Progress:  15 / 21   417
# Course number Progress:  16 / 21   393
# Course number Progress:  17 / 21   395
# Course number Progress:  18 / 21   472
# Course number Progress:  19 / 21   482
# Course number Progress:  20 / 21   494
# Course number Progress:  21 / 21   495
# Subject code loop : ENEV   8 / 17
# Course number Progress:  1 / 25   233
# Course number Progress:  2 / 25   422
# Course number Progress:  3 / 25   223
# Course number Progress:  4 / 25   261
# Course number Progress:  5 / 25   372
# Course number Progress:  6 / 25   321
# Course number Progress:  7 / 25   281
# Course number Progress:  8 / 25   334
# Course number Progress:  9 / 25   384
# Course number Progress:  10 / 25   480
# Course number Progress:  11 / 25   360
# Course number Progress:  12 / 25   421
# Course number Progress:  13 / 25   440
# Course number Progress:  14 / 25   462
# Course number Progress:  15 / 25   363
# Course number Progress:  16 / 25   383
# Course number Progress:  17 / 25   400
# Course number Progress:  18 / 25   435
# Course number Progress:  19 / 25   415
# Course number Progress:  20 / 25   469
# Course number Progress:  21 / 25   408
# Course number Progress:  22 / 25   445
# Course number Progress:  23 / 25   463
# Course number Progress:  24 / 25   475
# Course number Progress:  25 / 25   484
# Subject code loop : STAT   9 / 17
# Course number Progress:  1 / 1   289
# Subject code loop : ENSE   10 / 17
# Course number Progress:  1 / 17   352
# Course number Progress:  2 / 17   374
# Course number Progress:  3 / 17   353
# Course number Progress:  4 / 17   470
# Course number Progress:  5 / 17   471
# Course number Progress:  6 / 17   475
# Course number Progress:  7 / 17   400
# Course number Progress:  8 / 17   472
# Course number Progress:  9 / 17   350
# Course number Progress:  10 / 17   477
# Course number Progress:  11 / 17   473
# Course number Progress:  12 / 17   474
# Course number Progress:  13 / 17   479
# Course number Progress:  14 / 17   480
# Course number Progress:  15 / 17   481
# Course number Progress:  16 / 17   482
# Course number Progress:  17 / 17   483
# Subject code loop : BUS   11 / 17
# Course number Progress:  1 / 4   260
# Course number Progress:  2 / 4   250
# Course number Progress:  3 / 4   210
# Course number Progress:  4 / 4   302
# Subject code loop : ECON   12 / 17
# Course number Progress:  1 / 1   201
# Subject code loop : ENPE   13 / 17
# Course number Progress:  1 / 21   241
# Course number Progress:  2 / 21   251
# Course number Progress:  3 / 21   300
# Course number Progress:  4 / 21   360
# Course number Progress:  5 / 21   302
# Course number Progress:  6 / 21   370
# Course number Progress:  7 / 21   400
# Course number Progress:  8 / 21   410
# Course number Progress:  9 / 21   440
# Course number Progress:  10 / 21   450
# Course number Progress:  11 / 21   419
# Course number Progress:  12 / 21   486
# Course number Progress:  13 / 21   340
# Course number Progress:  14 / 21   380
# Course number Progress:  15 / 21   435
# Course number Progress:  16 / 21   448
# Course number Progress:  17 / 21   470
# Course number Progress:  18 / 21   475
# Course number Progress:  19 / 21   490
# Course number Progress:  20 / 21   491
# Course number Progress:  21 / 21   492
# Subject code loop : GEOL   14 / 17
# Course number Progress:  1 / 2   102
# Course number Progress:  2 / 2   270
# Subject code loop : ENIN   15 / 17
# Course number Progress:  1 / 21   233
# Course number Progress:  2 / 21   253
# Course number Progress:  3 / 21   350
# Course number Progress:  4 / 21   355
# Course number Progress:  5 / 21   433
# Course number Progress:  6 / 21   453
# Course number Progress:  7 / 21   456
# Course number Progress:  8 / 21   241
# Course number Progress:  9 / 21   331
# Course number Progress:  10 / 21   343
# Course number Progress:  11 / 21   430
# Course number Progress:  12 / 21   440
# Course number Progress:  13 / 21   340
# Course number Progress:  14 / 21   349
# Course number Progress:  15 / 21   400
# Course number Progress:  16 / 21   444
# Course number Progress:  17 / 21   413
# Course number Progress:  18 / 21   370
# Course number Progress:  19 / 21   445
# Course number Progress:  20 / 21   448
# Course number Progress:  21 / 21   455
# Subject code loop : ENE   16 / 17
# Course number Progress:  1 / 2   261
# Course number Progress:  2 / 2   223
# Subject code loop : BIOL   17 / 17
# Course number Progress:  1 / 1   233

# %%
# SSE_file = 'software course'
# PSE_file = 'petroleum course'
# ISE_file = 'industrial course'
# EVSE_file = 'environmental course'
# ESE_file = 'electronic course'
# AllCourse_file = 'all course'

storeInfo(SSE_course, SSE_file)
storeInfo(PSE_course, PSE_file)
storeInfo(ISE_course, ISE_file)
storeInfo(EVSE_course, EVSE_file)
storeInfo(ESE_course, ESE_file)
storeInfo(ALL_course, AllCourse_file)

# %%
def parseSecPage(sec_dict,html):
    soup = BeautifulSoup(html, "html.parser") # Make the soup for the html

    # Check the class if in the this semester
    result = re.findall(r'No classes were found that meet your search criteria',soup.text)
    if len(result)==1: 
        print("The class is not available for this semester")
        return
        # raise Exception('The class is not available for this semester')

    tables = soup.find_all('table',{'class':'datadisplaytable','summary':'This layout table is used to present the sections found'})[0]
    table_list = list(tables.children)[2:] # First two elements is not needed for the parsing the section page
    
    table_feature = ['type','time','days','loc','date_range','schedule_type','instructors']
    # Looping four elements as a group, picking first and third one as title and time, other is '/n'
    for title_tag,time_table in zip(table_list[0::4],table_list[2::4]):

        # Extract titles in the page
        extra_index = 0
        titles = title_tag.text.split(' - ')
        name = eliminate(titles[0])
        if not eliminate(titles[1]).isdigit(): 
            name = name + '-' + eliminate(titles[1])
            extra_index = 1
        course_code = eliminate(titles[1 + extra_index])
        title = eliminate(titles[2 + extra_index])
        section_num = eliminate(titles[3+ extra_index])

        # Extract term info
        term_text = re.findall(r'Associated\ Term:.*', time_table.text)
        if len(term_text):
            term_text = term_text[0]
            term = term_text.split(':')[-1]
            term = eliminate(term)

        # Extract time info for the lecture, exam and lab from each table
        cells = time_table.find_all('td',class_='dddefault')[1:]
        for index, cell in enumerate(cells):
            feat_index = index % len(table_feature)
            if feat_index == 0: 
                sec_dict['name'].append(name)
                sec_dict['course_code'].append(course_code)
                sec_dict['title'].append(title)
                sec_dict['section_num'].append(section_num)
                sec_dict['term'].append(term)
            feature = table_feature[feat_index]
            sec_dict[feature].append(cell.text)

# %% [markdown]
# Parse the course time information page for 202110

# %%
# term_in = '202110'
# section_dict_202110={
#     'name':[],
#     'course_code':[],
#     'title':[],
#     'section_num':[],
#     'term':[],
#     'type':[],
#     'time':[],
#     'days':[],
#     'loc':[],
#     'date_range':[],
#     'schedule_type':[],
#     'instructors':[]
# }

sec_202110 = copy.deepcopy(TempSec)
sec_202030 = copy.deepcopy(TempSec)
sec_202020 = copy.deepcopy(TempSec)
sec_list = [sec_202110, sec_202030, sec_202020]

for section, term_in in zip(sec_list, term_ins):
    section_para['term_in'] = term_in
    subjCodeLoop(section_url, section_para, allCourse_dict, section, parse_method=parseSecPage)
    storeInfo(section, term_in)
# file_name = "setion 202110"
# storeInfo(sec_202110, file_name)
# Out:
# urse number Progress:  7 / 15   315
# Course number Progress:  8 / 15   330
# Course number Progress:  9 / 15   375
# Course number Progress:  10 / 15   405
# The class is not available for this semester
# Course number Progress:  11 / 15   425
# The class is not available for this semester
# Course number Progress:  12 / 15   427
# Course number Progress:  13 / 15   335
# Course number Progress:  14 / 15   350
# Course number Progress:  15 / 15   372
# Subject code loop : ENGL   5 / 17
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 17
# Course number Progress:  1 / 3   119
# Course number Progress:  2 / 3   112
# Course number Progress:  3 / 3   201
# Subject code loop : ENEL   7 / 17
# Course number Progress:  1 / 21   280
# The class is not available for this semester
# Course number Progress:  2 / 21   281
# The class is not available for this semester
# Course number Progress:  3 / 21   282
# Course number Progress:  4 / 21   384
# The class is not available for this semester
# Course number Progress:  5 / 21   380
# The class is not available for this semester
# Course number Progress:  6 / 21   387
# Course number Progress:  7 / 21   487
# The class is not available for this semester
# Course number Progress:  8 / 21   489
# Course number Progress:  9 / 21   389
# The class is not available for this semester
# Course number Progress:  10 / 21   484
# Course number Progress:  11 / 21   383
# The class is not available for this semester
# Course number Progress:  12 / 21   390
# The class is not available for this semester
# Course number Progress:  13 / 21   371
# Course number Progress:  14 / 21   400
# The class is not available for this semester
# Course number Progress:  15 / 21   417
# Course number Progress:  16 / 21   393
# The class is not available for this semester
# Course number Progress:  17 / 21   395
# Error at  {'term_in': '202030', 'subj_in': 'ENEL', 'crse_in': '472', 'schd_in': ''}
# list index out of range
# Course number Progress:  18 / 21   472
# The class is not available for this semester
# Course number Progress:  19 / 21   482
# The class is not available for this semester
# Course number Progress:  20 / 21   494
# The class is not available for this semester
# Course number Progress:  21 / 21   495
# Subject code loop : ENEV   8 / 17
# The class is not available for this semester
# Course number Progress:  1 / 25   233
# The class is not available for this semester
# Course number Progress:  2 / 25   422
# Course number Progress:  3 / 25   223
# Course number Progress:  4 / 25   261
# Course number Progress:  5 / 25   372
# Course number Progress:  6 / 25   321
# The class is not available for this semester
# Course number Progress:  7 / 25   281
# The class is not available for this semester
# Course number Progress:  8 / 25   334
# The class is not available for this semester
# Course number Progress:  9 / 25   384
# The class is not available for this semester
# Course number Progress:  10 / 25   480
# The class is not available for this semester
# Course number Progress:  11 / 25   360
# The class is not available for this semester
# Course number Progress:  12 / 25   421
# The class is not available for this semester
# Course number Progress:  13 / 25   440
# The class is not available for this semester
# Course number Progress:  14 / 25   462
# Course number Progress:  15 / 25   363
# Course number Progress:  16 / 25   383
# Course number Progress:  17 / 25   400
# Course number Progress:  18 / 25   435
# The class is not available for this semester
# Course number Progress:  19 / 25   415
# The class is not available for this semester
# Course number Progress:  20 / 25   469
# Course number Progress:  21 / 25   408
# Course number Progress:  22 / 25   445
# The class is not available for this semester
# Course number Progress:  23 / 25   463
# The class is not available for this semester
# Course number Progress:  24 / 25   475
# Course number Progress:  25 / 25   484
# Subject code loop : STAT   9 / 17
# The class is not available for this semester
# Course number Progress:  1 / 1   289
# Subject code loop : ENSE   10 / 17
# Course number Progress:  1 / 17   352
# Course number Progress:  2 / 17   374
# The class is not available for this semester
# Course number Progress:  3 / 17   353
# The class is not available for this semester
# Course number Progress:  4 / 17   470
# The class is not available for this semester
# Course number Progress:  5 / 17   471
# The class is not available for this semester
# Course number Progress:  6 / 17   475
# Course number Progress:  7 / 17   400
# Course number Progress:  8 / 17   472
# The class is not available for this semester
# Course number Progress:  9 / 17   350
# The class is not available for this semester
# Course number Progress:  10 / 17   477
# The class is not available for this semester
# Course number Progress:  11 / 17   473
# The class is not available for this semester
# Course number Progress:  12 / 17   474
# Course number Progress:  13 / 17   479
# The class is not available for this semester
# Course number Progress:  14 / 17   480
# The class is not available for this semester
# Course number Progress:  15 / 17   481
# The class is not available for this semester
# Course number Progress:  16 / 17   482
# Course number Progress:  17 / 17   483
# Subject code loop : BUS   11 / 17
# Course number Progress:  1 / 4   260
# Course number Progress:  2 / 4   250
# Course number Progress:  3 / 4   210
# Course number Progress:  4 / 4   302
# Subject code loop : ECON   12 / 17
# Course number Progress:  1 / 1   201
# Subject code loop : ENPE   13 / 17
# Course number Progress:  1 / 21   241
# The class is not available for this semester
# Course number Progress:  2 / 21   251
# Course number Progress:  3 / 21   300
# Course number Progress:  4 / 21   360
# The class is not available for this semester
# Course number Progress:  5 / 21   302
# The class is not available for this semester
# Course number Progress:  6 / 21   370
# Course number Progress:  7 / 21   400
# Course number Progress:  8 / 21   410
# Course number Progress:  9 / 21   440
# Course number Progress:  10 / 21   450
# The class is not available for this semester
# Course number Progress:  11 / 21   419
# The class is not available for this semester
# Course number Progress:  12 / 21   486
# The class is not available for this semester
# Course number Progress:  13 / 21   340
# Course number Progress:  14 / 21   380
# The class is not available for this semester
# Course number Progress:  15 / 21   435
# The class is not available for this semester
# Course number Progress:  16 / 21   448
# Course number Progress:  17 / 21   470
# The class is not available for this semester
# Course number Progress:  18 / 21   475
# The class is not available for this semester
# Course number Progress:  19 / 21   490
# The class is not available for this semester
# Course number Progress:  20 / 21   491
# The class is not available for this semester
# Course number Progress:  21 / 21   492
# Subject code loop : GEOL   14 / 17
# Course number Progress:  1 / 2   102
# The class is not available for this semester
# Course number Progress:  2 / 2   270
# Subject code loop : ENIN   15 / 17
# The class is not available for this semester
# Course number Progress:  1 / 21   233
# The class is not available for this semester
# Course number Progress:  2 / 21   253
# Course number Progress:  3 / 21   350
# The class is not available for this semester
# Course number Progress:  4 / 21   355
# The class is not available for this semester
# Course number Progress:  5 / 21   433
# The class is not available for this semester
# Course number Progress:  6 / 21   453
# The class is not available for this semester
# Course number Progress:  7 / 21   456
# The class is not available for this semester
# Course number Progress:  8 / 21   241
# Course number Progress:  9 / 21   331
# Course number Progress:  10 / 21   343
# The class is not available for this semester
# Course number Progress:  11 / 21   430
# The class is not available for this semester
# Course number Progress:  12 / 21   440
# Course number Progress:  13 / 21   340
# Course number Progress:  14 / 21   349
# Course number Progress:  15 / 21   400
# Course number Progress:  16 / 21   444
# The class is not available for this semester
# Course number Progress:  17 / 21   413
# The class is not available for this semester
# Course number Progress:  18 / 21   370
# The class is not available for this semester
# Course number Progress:  19 / 21   445
# The class is not available for this semester
# Course number Progress:  20 / 21   448
# The class is not available for this semester
# Course number Progress:  21 / 21   455
# Subject code loop : ENE   16 / 17
# The class is not available for this semester
# Course number Progress:  1 / 2   261
# The class is not available for this semester
# Course number Progress:  2 / 2   223
# Subject code loop : BIOL   17 / 17
# The class is not available for this semester
# Course number Progress:  1 / 1   233
# Subject code loop : CHEM   1 / 17
# Course number Progress:  1 / 3   104
# The class is not available for this semester
# Course number Progress:  2 / 3   140
# Course number Progress:  3 / 3   105
# Subject code loop : ENGG   2 / 17
# Course number Progress:  1 / 9   123
# Course number Progress:  2 / 9   140
# Course number Progress:  3 / 9   100
# The class is not available for this semester
# Course number Progress:  4 / 9   303
# The class is not available for this semester
# Course number Progress:  5 / 9   401
# Course number Progress:  6 / 9   141
# Course number Progress:  7 / 9   330
# The class is not available for this semester
# Course number Progress:  8 / 9   3330
# The class is not available for this semester
# Course number Progress:  9 / 9   411
# Subject code loop : MATH   3 / 17
# Course number Progress:  1 / 5   110
# Course number Progress:  2 / 5   122
# Course number Progress:  3 / 5   111
# Course number Progress:  4 / 5   213
# Course number Progress:  5 / 5   217
# Subject code loop : CS   4 / 17
# Course number Progress:  1 / 15   110
# Course number Progress:  2 / 15   115
# Course number Progress:  3 / 15   210
# Course number Progress:  4 / 15   215
# Course number Progress:  5 / 15   340
# The class is not available for this semester
# Course number Progress:  6 / 15   205
# The class is not available for this semester
# Course number Progress:  7 / 15   315
# The class is not available for this semester
# Course number Progress:  8 / 15   330
# The class is not available for this semester
# Course number Progress:  9 / 15   375
# The class is not available for this semester
# Course number Progress:  10 / 15   405
# The class is not available for this semester
# Course number Progress:  11 / 15   425
# The class is not available for this semester
# Course number Progress:  12 / 15   427
# Course number Progress:  13 / 15   335
# Course number Progress:  14 / 15   350
# The class is not available for this semester
# Course number Progress:  15 / 15   372
# Subject code loop : ENGL   5 / 17
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 17
# Course number Progress:  1 / 3   119
# The class is not available for this semester
# Course number Progress:  2 / 3   112
# The class is not available for this semester
# Course number Progress:  3 / 3   201
# Subject code loop : ENEL   7 / 17
# The class is not available for this semester
# Course number Progress:  1 / 21   280
# Course number Progress:  2 / 21   281
# Course number Progress:  3 / 21   282
# The class is not available for this semester
# Course number Progress:  4 / 21   384
# Course number Progress:  5 / 21   380
# The class is not available for this semester
# Course number Progress:  6 / 21   387
# The class is not available for this semester
# Course number Progress:  7 / 21   487
# The class is not available for this semester
# Course number Progress:  8 / 21   489
# The class is not available for this semester
# Course number Progress:  9 / 21   389
# The class is not available for this semester
# Course number Progress:  10 / 21   484
# The class is not available for this semester
# Course number Progress:  11 / 21   383
# Course number Progress:  12 / 21   390
# The class is not available for this semester
# Course number Progress:  13 / 21   371
# The class is not available for this semester
# Course number Progress:  14 / 21   400
# The class is not available for this semester
# Course number Progress:  15 / 21   417
# The class is not available for this semester
# Course number Progress:  16 / 21   393
# The class is not available for this semester
# Course number Progress:  17 / 21   395
# The class is not available for this semester
# Course number Progress:  18 / 21   472
# The class is not available for this semester
# Course number Progress:  19 / 21   482
# The class is not available for this semester
# Course number Progress:  20 / 21   494
# The class is not available for this semester
# Course number Progress:  21 / 21   495
# Subject code loop : ENEV   8 / 17
# The class is not available for this semester
# Course number Progress:  1 / 25   233
# The class is not available for this semester
# Course number Progress:  2 / 25   422
# Course number Progress:  3 / 25   223
# The class is not available for this semester
# Course number Progress:  4 / 25   261
# The class is not available for this semester
# Course number Progress:  5 / 25   372
# The class is not available for this semester
# Course number Progress:  6 / 25   321
# Course number Progress:  7 / 25   281
# Course number Progress:  8 / 25   334
# Course number Progress:  9 / 25   384
# Course number Progress:  10 / 25   480
# The class is not available for this semester
# Course number Progress:  11 / 25   360
# The class is not available for this semester
# Course number Progress:  12 / 25   421
# The class is not available for this semester
# Course number Progress:  13 / 25   440
# The class is not available for this semester
# Course number Progress:  14 / 25   462
# The class is not available for this semester
# Course number Progress:  15 / 25   363
# The class is not available for this semester
# Course number Progress:  16 / 25   383
# The class is not available for this semester
# Course number Progress:  17 / 25   400
# The class is not available for this semester
# Course number Progress:  18 / 25   435
# The class is not available for this semester
# Course number Progress:  19 / 25   415
# The class is not available for this semester
# Course number Progress:  20 / 25   469
# The class is not available for this semester
# Course number Progress:  21 / 25   408
# The class is not available for this semester
# Course number Progress:  22 / 25   445
# The class is not available for this semester
# Course number Progress:  23 / 25   463
# The class is not available for this semester
# Course number Progress:  24 / 25   475
# The class is not available for this semester
# Course number Progress:  25 / 25   484
# Subject code loop : STAT   9 / 17
# Course number Progress:  1 / 1   289
# Subject code loop : ENSE   10 / 17
# The class is not available for this semester
# Course number Progress:  1 / 17   352
# The class is not available for this semester
# Course number Progress:  2 / 17   374
# Course number Progress:  3 / 17   353
# The class is not available for this semester
# Course number Progress:  4 / 17   470
# The class is not available for this semester
# Course number Progress:  5 / 17   471
# The class is not available for this semester
# Course number Progress:  6 / 17   475
# The class is not available for this semester
# Course number Progress:  7 / 17   400
# The class is not available for this semester
# Course number Progress:  8 / 17   472
# The class is not available for this semester
# Course number Progress:  9 / 17   350
# The class is not available for this semester
# Course number Progress:  10 / 17   477
# The class is not available for this semester
# Course number Progress:  11 / 17   473
# The class is not available for this semester
# Course number Progress:  12 / 17   474
# The class is not available for this semester
# Course number Progress:  13 / 17   479
# The class is not available for this semester
# Course number Progress:  14 / 17   480
# The class is not available for this semester
# Course number Progress:  15 / 17   481
# The class is not available for this semester
# Course number Progress:  16 / 17   482
# The class is not available for this semester
# Course number Progress:  17 / 17   483
# Subject code loop : BUS   11 / 17
# Course number Progress:  1 / 4   260
# Course number Progress:  2 / 4   250
# Course number Progress:  3 / 4   210
# Course number Progress:  4 / 4   302
# Subject code loop : ECON   12 / 17
# Course number Progress:  1 / 1   201
# Subject code loop : ENPE   13 / 17
# The class is not available for this semester
# Course number Progress:  1 / 21   241
# Course number Progress:  2 / 21   251
# Course number Progress:  3 / 21   300
# The class is not available for this semester
# Course number Progress:  4 / 21   360
# The class is not available for this semester
# Course number Progress:  5 / 21   302
# The class is not available for this semester
# Course number Progress:  6 / 21   370
# The class is not available for this semester
# Course number Progress:  7 / 21   400
# The class is not available for this semester
# Course number Progress:  8 / 21   410
# The class is not available for this semester
# Course number Progress:  9 / 21   440
# The class is not available for this semester
# Course number Progress:  10 / 21   450
# The class is not available for this semester
# Course number Progress:  11 / 21   419
# The class is not available for this semester
# Course number Progress:  12 / 21   486
# The class is not available for this semester
# Course number Progress:  13 / 21   340
# The class is not available for this semester
# Course number Progress:  14 / 21   380
# The class is not available for this semester
# Course number Progress:  15 / 21   435
# The class is not available for this semester
# Course number Progress:  16 / 21   448
# The class is not available for this semester
# Course number Progress:  17 / 21   470
# The class is not available for this semester
# Course number Progress:  18 / 21   475
# The class is not available for this semester
# Course number Progress:  19 / 21   490
# The class is not available for this semester
# Course number Progress:  20 / 21   491
# The class is not available for this semester
# Course number Progress:  21 / 21   492
# Subject code loop : GEOL   14 / 17
# The class is not available for this semester
# Course number Progress:  1 / 2   102
# The class is not available for this semester
# Course number Progress:  2 / 2   270
# Subject code loop : ENIN   15 / 17
# Course number Progress:  1 / 21   233
# Course number Progress:  2 / 21   253
# Course number Progress:  3 / 21   350
# The class is not available for this semester
# Course number Progress:  4 / 21   355
# The class is not available for this semester
# Course number Progress:  5 / 21   433
# The class is not available for this semester
# Course number Progress:  6 / 21   453
# The class is not available for this semester
# Course number Progress:  7 / 21   456
# Course number Progress:  8 / 21   241
# The class is not available for this semester
# Course number Progress:  9 / 21   331
# The class is not available for this semester
# Course number Progress:  10 / 21   343
# The class is not available for this semester
# Course number Progress:  11 / 21   430
# The class is not available for this semester
# Course number Progress:  12 / 21   440
# The class is not available for this semester
# Course number Progress:  13 / 21   340
# The class is not available for this semester
# Course number Progress:  14 / 21   349
# The class is not available for this semester
# Course number Progress:  15 / 21   400
# The class is not available for this semester
# Course number Progress:  16 / 21   444
# The class is not available for this semester
# Course number Progress:  17 / 21   413
# The class is not available for this semester
# Course number Progress:  18 / 21   370
# The class is not available for this semester
# Course number Progress:  19 / 21   445
# The class is not available for this semester
# Course number Progress:  20 / 21   448
# The class is not available for this semester
# Course number Progress:  21 / 21   455
# Subject code loop : ENE   16 / 17
# The class is not available for this semester
# Course number Progress:  1 / 2   261
# The class is not available for this semester
# Course number Progress:  2 / 2   223
# Subject code loop : BIOL   17 / 17
# The class is not available for this semester
# Course number Progress:  1 / 1   233

# %%
# section_url = 'https://banner.uregina.ca:17023/ssbprod/bwckctlg.p_disp_listcrse'
# section_para ={
#     'term_in':'202030',
#     'subj_in':'ENSE',
#     'crse_in':'271',
#     'schd_in':''
# }
# section_dict_202030={
#     'name':[],
#     'course_code':[],
#     'title':[],
#     'section_num':[],
#     'term':[],
#     'type':[],
#     'time':[],
#     'days':[],
#     'loc':[],
#     'date_range':[],
#     'schedule_type':[],
#     'instructors':[]
# }
# subjCodeLoop(section_url, section_para, software_dict, section_dict_202030, parse_method=parseSecPage)
# file_name = "software 202030"
# storeInfo(section_dict_202030, file_name)
# Out:
# Subject code loop : CHEM   1 / 11
# Course number Progress:  1 / 1   104
# Subject code loop : ENGG   2 / 11
# Course number Progress:  1 / 5   123
# Course number Progress:  2 / 5   140
# Course number Progress:  3 / 5   100
# Course number Progress:  4 / 5   303
# The class is not available for this semester
# Course number Progress:  5 / 5   410
# Subject code loop : MATH   3 / 11
# Course number Progress:  1 / 4   110
# Course number Progress:  2 / 4   122
# Course number Progress:  3 / 4   111
# Course number Progress:  4 / 4   213
# Subject code loop : CS   4 / 11
# Course number Progress:  1 / 13   110
# Course number Progress:  2 / 13   115
# Course number Progress:  3 / 13   210
# Course number Progress:  4 / 13   215
# Course number Progress:  5 / 13   340
# The class is not available for this semester
# Course number Progress:  6 / 13   205
# The class is not available for this semester
# Course number Progress:  7 / 13   315
# Course number Progress:  8 / 13   330
# Course number Progress:  9 / 13   350
# Course number Progress:  10 / 13   375
# Course number Progress:  11 / 13   405
# The class is not available for this semester
# Course number Progress:  12 / 13   425
# The class is not available for this semester
# Course number Progress:  13 / 13   427
# Subject code loop : ENGL   5 / 11
# Course number Progress:  1 / 1   100
# Subject code loop : PHYS   6 / 11
# Course number Progress:  1 / 1   119
# Subject code loop : ENEL   7 / 11
# The class is not available for this semester
# Course number Progress:  1 / 7   281
# The class is not available for this semester
# Course number Progress:  2 / 7   282
# Course number Progress:  3 / 7   384
# The class is not available for this semester
# Course number Progress:  4 / 7   380
# The class is not available for this semester
# Course number Progress:  5 / 7   387
# Course number Progress:  6 / 7   487
# The class is not available for this semester
# Course number Progress:  7 / 7   489
# Subject code loop : STAT   8 / 11
# The class is not available for this semester
# Course number Progress:  1 / 1   289
# Subject code loop : ENSE   9 / 11
# Course number Progress:  1 / 17   352
# Course number Progress:  2 / 17   374
# The class is not available for this semester
# Course number Progress:  3 / 17   353
# The class is not available for this semester
# Course number Progress:  4 / 17   470
# The class is not available for this semester
# Course number Progress:  5 / 17   471
# The class is not available for this semester
# Course number Progress:  6 / 17   475
# Course number Progress:  7 / 17   400
# Course number Progress:  8 / 17   472
# The class is not available for this semester
# Course number Progress:  9 / 17   350
# The class is not available for this semester
# Course number Progress:  10 / 17   477
# The class is not available for this semester
# Course number Progress:  11 / 17   473
# The class is not available for this semester
# Course number Progress:  12 / 17   474
# Course number Progress:  13 / 17   479
# The class is not available for this semester
# Course number Progress:  14 / 17   480
# The class is not available for this semester
# Course number Progress:  15 / 17   481
# The class is not available for this semester
# Course number Progress:  16 / 17   482
# Course number Progress:  17 / 17   483
# Subject code loop : BUS   10 / 11
# Course number Progress:  1 / 1   260
# Subject code loop : ECON   11 / 11
# Course number Progress:  1 / 1   201

# %%
import json

# %% [markdown]
# section_dict_202030={
#     'name':[],
#     'course_code':[],
#     'title':[],
#     'section_num':[],
#     'term':[],
#     'type':[],
#     'time':[],
#     'days':[],
#     'loc':[],
#     'date_range':[],
#     'schedule_type':[],
#     'instructors':[]
# }
# software_course = {
#         "short_name" : [],
#         "title" : [],
#         "faculty" : [],
#         "course_num" : [],
#         "credit" : [],
#         "prerequisite" : [],
#         "description" : []
#     }

# %%
def course_JSON(course_dict, section_dict, file_loc):
    course_json = {
        "term": None,
        "short_name" : None,
        "title" : None,
        "faculty" : None,
        "credit" : None,
        "description" : None,
        "prerequisite" : None,
        'section':[]
    }

    short_name_list = course_dict["short_name"]
    for index, short_name in enumerate(short_name_list):
        # print(index, short_name)
        course_json['section'], course_json['term'] = exctSectionTerm(short_name, section_dict)
        # course_json['term'] = exctTerm(short_name, section_dict)
        key_list = list(course_json.keys())
        key_list.remove('section')
        key_list.remove('term')
        for key in key_list:
            course_json[key] = course_dict[key][index]
        genJSON(course_json, file_loc + short_name + '.json')

# %%
def exctSectionTerm(short_name, section_dict):
    section_list = []
    sect_short_list = section_dict['title']
    sect_indexs = [i for i, sect_short_name in enumerate(sect_short_list) if sect_short_name == short_name]

    # In case the this semester has no sections for the class
    if len(sect_indexs) == 0: return [], 'No class for the term'

    for sect_index in sect_indexs:
        if section_dict['schedule_type'][sect_index] == 'Examination':
            continue

        section={
            'course_ID': section_dict['course_code'][sect_index],
            'section_num': section_dict['section_num'][sect_index],
            'instructors':section_dict['instructors'][sect_index],
            'days': section_dict['days'][sect_index],
            'time': section_dict['time'][sect_index],
            'loc': section_dict['loc'][sect_index],
            'course_type': section_dict['schedule_type'][sect_index],
            'exam_days': None,
            'exam_date': None,
            'exam_time': None 
        }
        if section['course_type'] == 'Lecture':
           section['exam_days'] = section_dict['days'][sect_index + 1]
           section['exam_date'] = section_dict['date_range'][sect_index + 1]
           section['exam_time'] = section_dict['time'][sect_index + 1]
        section_list.append(section)

    term_index = sect_indexs[0]
    term  = section_dict['term'][term_index]
    return section_list, term

# %%
def genJSON(course_json, file_loc):
    j = json.dumps(course_json)
    with open(file_loc,'w') as f:
        f.write(j)
        f.close()

# %%
file_locs = [term + '/' for term in term_ins]
# file_loc = 'JSON/202030/'
for section, file_loc in zip(sec_list, file_locs):
    course_JSON(ALL_course, section, file_loc)
# course_JSON(software_course,section_dict_202030, file_loc)

print(file_loc, "Finished")
# Out:
# JSON/202030/ Finished

# %%
# file_loc = 'JSON/202110/'
# course_JSON(software_course,section_dict_202110, file_loc)
# print(file_loc, "Finished")
# Out:
# JSON/202110/ Finished

# %%
def faculty_JSON(course_dict, file_loc, faculty_name):
    course_json = {
        "short_name" : None,
        "title" : None,
        "faculty" : None,
        "credit" : None,
        "description" : None,
        "prerequisite" : None,
    }
    short_name_list = course_dict["short_name"]
    json_list = []
    for index, short_name in enumerate(short_name_list):
        for key in course_json.keys():
            course_json[key] = course_dict[key][index]
        json_list.append(course_json)
        course_json = copy.deepcopy(course_json)
    genJSON(json_list, file_loc + faculty_name + '.json')

# %%
file_loc = ''
if not len(cou_dict) == len(fau_names): print('Two list have diff length')
for cou_dict, faculty in zip(cou_dict_list, fau_names):
    faculty_JSON(cou_dict, file_loc, faculty)
# faculty_JSON(software_course, file_loc, 'software')
